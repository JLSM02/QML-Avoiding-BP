# %% [markdown]
# # Looking for BP using the $\hat{Z}_1 \hat{Z}_2$ observable
#
# We start by studying a simple case: the minimization of an expectation value of a simple, two qubits, observable. In order to look for BP, we will study the cocentration of the cost function and its gradient using different number of qubits.
#
# In order to do that, we calculate the variances of the observable and its derivatives. If there is a BP, one should expect to see an exponential reduction of the variances as the number of qubits increase.
#
# First, we import our custom modules that includes functions capable of expand the observable, build different ansatzs and calculate the variances for different numbers of qubits.

# %%
import sys
import numpy as np
sys.path.append('../../')

from src import customFunc as cf, ansatzs as anz

from qiskit.quantum_info import SparsePauliOp

# %% [markdown]
# We define the observable:

# %%
observable = SparsePauliOp.from_list([("ZZ",1)])
print(observable)
# Out:
# SparsePauliOp(['ZZ'],
#               coeffs=[1.+0.j])

# %% [markdown]
# We use our custom deep ansatz:

# %%
# set the number of layer per qubit
def ansatz_fun(num_qubits):
    return anz.build_deep_ansatz(num_qubits, 10)

# %% [markdown]
# Calculate the variances concentration:

# %%
data = cf.variance_vs_nQubits(ansatz_fun, 2, 15, observable, 0, 100, print_info=True, plot_info=True, do_regress=True)
# Out:
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.17106363678777672
# Varianza de la derivada: 0.0685642720504596
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.09961247458460429
# Varianza de la derivada: 0.0642917301865603
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.05724438187506544
# Varianza de la derivada: 0.029148776096844783
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.032514833867120105
# Varianza de la derivada: 0.01600746015259398
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.018552427834827353
# Varianza de la derivada: 0.003427127204631696
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.008135107243986767
# Varianza de la derivada: 0.0017178789918238053
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.004517540451428471
# Varianza de la derivada: 0.0008758269500714908
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0019102447040787787
# Varianza de la derivada: 0.00047074543126251664
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0009075375282578314
# Varianza de la derivada: 0.00023197367381621507
#
# =====================================================
# Calculando varianzas con 11 qubits.
#
# Varianza del valor esperado: 0.0006794720337015602
# Varianza de la derivada: 0.00023806456396840183
#
# =====================================================
# Calculando varianzas con 12 qubits.
#
# Varianza del valor esperado: 0.0003896620350775377
# Varianza de la derivada: 6.321070114161951e-05
#
# =====================================================
# Calculando varianzas con 13 qubits.
#
# Varianza del valor esperado: 0.00012299393788731925
# Varianza de la derivada: 2.4862739048994214e-05
#
# =====================================================
# Calculando varianzas con 14 qubits.
#
# Varianza del valor esperado: 0.00010527642465241283
# Varianza de la derivada: 2.8767945571960952e-05
#
# =====================================================
# Calculando varianzas con 15 qubits.
#
# Varianza del valor esperado: 5.908943988582087e-05
# Varianza de la derivada: 1.0274223483404853e-05
#
# =====================================================
# Pendiente para valor esperado: -0.6356657189479367.
# R^2 para valor esperado: 0.9958224080948559.
#
# =====================================================
# Pendiente para derivada: -0.7068383624066817.
# R^2 para derivada: 0.985094137529522.

# %% [markdown]
# We can see a clearly decreasing linear tendecy. Taking into account that the vertical axis is in logaritmic scale, we conclude that we have found an exponential concentration of the variances, thus, a barren plateau.

# %%
data_noise = []
for noise_scale in np.linspace(0, 0.15, 4):
    data_noise.append(cf.noisy_variance_vs_nQubits(ansatz_fun, 2, 10, observable, 0, 100, print_info=True, plot_info=True, do_regress=True))
# Out:
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.17898336322890582
# Varianza de la derivada: 0.11958972071770563
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.09485364965565773
# Varianza de la derivada: 0.05776391802289055
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.06453883211992857
# Varianza de la derivada: 0.013401105228062619
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.02627919077447498
# Varianza de la derivada: 0.015873552593596713
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.015204947408621211
# Varianza de la derivada: 0.004373455142787432
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.00834143802067807
# Varianza de la derivada: 0.005029339715236417
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.004523911599377063
# Varianza de la derivada: 0.001760807611970516
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0018304305572425191
# Varianza de la derivada: 0.0011589967874662296
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0009225091465304043
# Varianza de la derivada: 0.00043776268041055354
#
# =====================================================
# Pendiente para valor esperado: -0.6563079530174628.
# R^2 para valor esperado: 0.9954211345541687.
#
# =====================================================
# Pendiente para derivada: -0.6562584066919203.
# R^2 para derivada: 0.9662844808222241.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.1793719224086213
# Varianza de la derivada: 0.06288994587459967
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.11351307165555186
# Varianza de la derivada: 0.02874444553637368
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.05805339849579837
# Varianza de la derivada: 0.016317717922631904
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.02722758484548244
# Varianza de la derivada: 0.008308360178921627
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.014682524191657968
# Varianza de la derivada: 0.0056490329754756395
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.008297825488038015
# Varianza de la derivada: 0.0020820911950646774
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0037541336981836023
# Varianza de la derivada: 0.0007577425952296187
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0020989594350434497
# Varianza de la derivada: 0.0009018706588436555
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0013264520124723108
# Varianza de la derivada: 0.0002592634861678679
#
# =====================================================
# Pendiente para valor esperado: -0.6377415368525557.
# R^2 para valor esperado: 0.9976463344904319.
#
# =====================================================
# Pendiente para derivada: -0.6645598099017006.
# R^2 para derivada: 0.9828575576894301.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.19249320758154082
# Varianza de la derivada: 0.12052893377795838
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.10748022729268306
# Varianza de la derivada: 0.060835083023664735
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.06911432876388274
# Varianza de la derivada: 0.014459928404941435
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.024270825558962157
# Varianza de la derivada: 0.008293985356005699
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.01345162031236188
# Varianza de la derivada: 0.003651104119573795
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.009325772496019338
# Varianza de la derivada: 0.0017176165037327718
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.004640992046596907
# Varianza de la derivada: 0.000974090526312563
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0021952499674651924
# Varianza de la derivada: 0.0004485532254673203
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0012260906565998285
# Varianza de la derivada: 0.0002485785295475971
#
# =====================================================
# Pendiente para valor esperado: -0.6376019061400605.
# R^2 para valor esperado: 0.9947437156294433.
#
# =====================================================
# Pendiente para derivada: -0.773918109718917.
# R^2 para derivada: 0.9889465669651213.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.22869330852144748
# Varianza de la derivada: 0.059720181023622504
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.10802321947964677
# Varianza de la derivada: 0.04086361827410882
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.05630428997186985
# Varianza de la derivada: 0.016535062826018684
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.028182041314138352
# Varianza de la derivada: 0.006910693043777763
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.014143881451356841
# Varianza de la derivada: 0.0041553266726082
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.009895146715028027
# Varianza de la derivada: 0.003822696554248741
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0034637401834373164
# Varianza de la derivada: 0.0009314822482876556
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0016545207357132846
# Varianza de la derivada: 0.0004235955085504377
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0013795960091763915
# Varianza de la derivada: 0.0002567669822400487
#
# =====================================================
# Pendiente para valor esperado: -0.6600392169201269.
# R^2 para valor esperado: 0.9922028318004293.
#
# =====================================================
# Pendiente para derivada: -0.6974951804682924.
# R^2 para derivada: 0.9828882222682772.

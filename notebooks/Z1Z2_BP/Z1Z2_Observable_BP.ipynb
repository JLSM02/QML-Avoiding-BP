# %% [markdown]
# # Looking for BP using the $\hat{Z}_1 \hat{Z}_2$ observable
#
# We start by studying a simple case: the minimization of an expectation value of a simple, two qubits, observable. In order to look for BP, we will study the cocentration of the cost function and its gradient using different number of qubits.
#
# In order to do that, we calculate the variances of the observable and its derivatives. If there is a BP, one should expect to see an exponential reduction of the variances as the number of qubits increase.
#
# First, we import our custom modules that includes functions capable of expand the observable, build different ansatzs and calculate the variances for different numbers of qubits.

# %%
import sys
import numpy as np
sys.path.append('../../')

from src import customFunc as cf, ansatzs as anz

from qiskit.quantum_info import SparsePauliOp

# %% [markdown]
# We define the observable:

# %%
observable = SparsePauliOp.from_list([("ZZ",1)])
print(observable)
# Out:
# SparsePauliOp(['ZZ'],
#               coeffs=[1.+0.j])

# %% [markdown]
# We use our custom deep ansatz:

# %%
# set the number of layer per qubit
def ansatz_fun(num_qubits):
    return anz.build_deep_ansatz(num_qubits, 10)

# %% [markdown]
# Calculate the variances concentration:

# %%
data = cf.variance_vs_nQubits(ansatz_fun, 2, 15, observable, 0, 100, print_info=True, plot_info=True, do_regress=True)
# Out:
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.19669641688119188
# Varianza de la derivada: 0.08563606083347321
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.14565525269293825
# Varianza de la derivada: 0.06563386225924579
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.05088698423481439
# Varianza de la derivada: 0.013182143120087399
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.02589028712478419
# Varianza de la derivada: 0.00673248146347064
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.015973111106719288
# Varianza de la derivada: 0.0032036802259244684
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.008908929660017356
# Varianza de la derivada: 0.0037409784221716985
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.005008910211056503
# Varianza de la derivada: 0.0010494002997586457
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0025178422202896344
# Varianza de la derivada: 0.000940968484338414
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0010286046403617808
# Varianza de la derivada: 0.00039241951183064387
#
# =====================================================
# Calculando varianzas con 11 qubits.
#
# Varianza del valor esperado: 0.0006168981079935093
# Varianza de la derivada: 9.317176269438054e-05
#
# =====================================================
# Calculando varianzas con 12 qubits.
#
# Varianza del valor esperado: 0.00028700593831445224
# Varianza de la derivada: 0.00011269151822401754
#
# =====================================================
# Calculando varianzas con 13 qubits.
#
# Varianza del valor esperado: 0.00014724549075396647
# Varianza de la derivada: 3.24132604314241e-05
#
# =====================================================
# Calculando varianzas con 14 qubits.
#
# Varianza del valor esperado: 7.812083979297194e-05
# Varianza de la derivada: 2.6594262785398097e-05
#
# =====================================================
# Calculando varianzas con 15 qubits.
#
# Varianza del valor esperado: 5.310688891048445e-05
# Varianza de la derivada: 1.3461403458802534e-05
#
# =====================================================
# Pendiente para valor esperado: -0.6532240335178428.
# R^2 para valor esperado: 0.9975225399443278.
#
# =====================================================
# Pendiente para derivada: -0.6748161029501598.
# R^2 para derivada: 0.9835423119768444.

# %% [markdown]
# We can see a clearly decreasing linear tendecy. Taking into account that the vertical axis is in logaritmic scale, we conclude that we have found an exponential concentration of the variances, thus, a barren plateau.

# %% [markdown]
# ### Noise induced BP

# %%
from qiskit.providers.fake_provider import FakeManila

fake_backend = FakeManila()

data_noise = []

for noise_scale in np.linspace(0, 0.15, 8):
    data_noise.append(cf.noisy_variance_vs_nQubits(ansatz_fun, fake_backend, noise_scale, 2, 10, observable, 0, 100, print_info=True, plot_info=True, do_regress=True))
# Out:
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.19338624992370604
# Varianza de la derivada: 0.07554877624511719
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.1313274444580078
# Varianza de la derivada: 0.029852342510223392
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.048505054855346674
# Varianza de la derivada: 0.014833509063720704
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.03371933898925781
# Varianza de la derivada: 0.008161091232299805
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.020363340377807616
# Varianza de la derivada: 0.004793326950073242
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.008452253723144532
# Varianza de la derivada: 0.004126203918457031
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0053552532196044925
# Varianza de la derivada: 0.0020212435722351076
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0024400878906250005
# Varianza de la derivada: 0.0008258524894714356
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0021363739013671875
# Varianza de la derivada: 0.0007717231750488282
#
# =====================================================
# Pendiente para valor esperado: -0.5961685958553316.
# R^2 para valor esperado: 0.9893097355847537.
#
# =====================================================
# Pendiente para derivada: -0.5627801726912244.
# R^2 para derivada: 0.979424886169373.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.007014700317382812
# Varianza de la derivada: 0.003703729248046875
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.0009331756591796875
# Varianza de la derivada: 0.00047607192993164065
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.001002714538574219
# Varianza de la derivada: 0.0004801806449890136
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0009195083618164062
# Varianza de la derivada: 0.0005668650627136231
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.0009479290008544922
# Varianza de la derivada: 0.00044774732589721673
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0006492218017578124
# Varianza de la derivada: 0.00045245895385742185
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0009680553436279296
# Varianza de la derivada: 0.0005869578361511231
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0009512496948242187
# Varianza de la derivada: 0.0004997730255126953
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0010933574676513672
# Varianza de la derivada: 0.00045973768234252926
#
# =====================================================
# Pendiente para valor esperado: -0.129931470441648.
# R^2 para valor esperado: 0.2655651013972236.
#
# =====================================================
# Pendiente para derivada: -0.13373075746763116.
# R^2 para derivada: 0.2914427837110658.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.0016150951385498046
# Varianza de la derivada: 0.0005533732414245606
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.0009578994750976562
# Varianza de la derivada: 0.0005425037384033204
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0009859298706054688
# Varianza de la derivada: 0.0005941394805908203
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0010195556640625
# Varianza de la derivada: 0.00045762739181518555
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.0007580791473388672
# Varianza de la derivada: 0.0005068813323974609
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0009350799560546876
# Varianza de la derivada: 0.0005318416595458985
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0008448223114013671
# Varianza de la derivada: 0.0005877994537353516
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0012783447265624997
# Varianza de la derivada: 0.000483393096923828
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.001057684326171875
# Varianza de la derivada: 0.0005961436271667479
#
# =====================================================
# Pendiente para valor esperado: -0.020382003988988817.
# R^2 para valor esperado: 0.0624011454778353.
#
# =====================================================
# Pendiente para derivada: 0.001342253722232408.
# R^2 para derivada: 0.001535872763926283.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.0009514999389648436
# Varianza de la derivada: 0.0004618263244628906
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.0009566116333007813
# Varianza de la derivada: 0.0005023551940917969
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0009199748992919924
# Varianza de la derivada: 0.00047168149948120124
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0010243362426757812
# Varianza de la derivada: 0.00040080604553222656
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.00113045654296875
# Varianza de la derivada: 0.0005036159515380859
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0009110607147216795
# Varianza de la derivada: 0.0004893112182617188
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0010326305389404297
# Varianza de la derivada: 0.00046721038818359374
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0010874557495117185
# Varianza de la derivada: 0.0005487948417663575
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.000916290283203125
# Varianza de la derivada: 0.0004833735466003418
#
# =====================================================
# Pendiente para valor esperado: 0.005793604461438203.
# R^2 para valor esperado: 0.03997711670871301.
#
# =====================================================
# Pendiente para derivada: 0.010468793532116636.
# R^2 para derivada: 0.11384191725013444.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.0009203170776367188
# Varianza de la derivada: 0.00043367919921875
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.0011510814666748045
# Varianza de la derivada: 0.00039984741210937494
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.001181138610839844
# Varianza de la derivada: 0.00046260795593261716
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0007740158081054687
# Varianza de la derivada: 0.0004449015617370606
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.0011407470703125
# Varianza de la derivada: 0.0004872942924499511
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.001120758056640625
# Varianza de la derivada: 0.0004702013969421386
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0009267192840576171
# Varianza de la derivada: 0.0005545893669128419
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0010993743896484376
# Varianza de la derivada: 0.0004494319915771485
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0009817947387695315
# Varianza de la derivada: 0.0005462360382080078
#
# =====================================================
# Pendiente para valor esperado: 9.625753365418711e-05.
# R^2 para valor esperado: 3.466233035030598e-06.
#
# =====================================================
# Pendiente para derivada: 0.02819488494693185.
# R^2 para derivada: 0.5350085673307777.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.00092642822265625
# Varianza de la derivada: 0.0005040240287780761
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.0008869766235351563
# Varianza de la derivada: 0.0005151580810546875
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0010675811767578126
# Varianza de la derivada: 0.0005390620231628419
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0007248210906982422
# Varianza de la derivada: 0.00045615043640136714
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.0009482574462890625
# Varianza de la derivada: 0.00043594923019409185
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0010384155273437498
# Varianza de la derivada: 0.0005410209655761719
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0008308177947998047
# Varianza de la derivada: 0.0004327796936035156
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.001035821533203125
# Varianza de la derivada: 0.0005934673309326171
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0009847198486328125
# Varianza de la derivada: 0.0004929901123046876
#
# =====================================================
# Pendiente para valor esperado: 0.009458714810449331.
# R^2 para valor esperado: 0.04345934495124707.
#
# =====================================================
# Pendiente para derivada: 0.0011236249628680639.
# R^2 para derivada: 0.0008379859594621988.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.0009465312957763672
# Varianza de la derivada: 0.0005583473205566406
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.0008190475463867188
# Varianza de la derivada: 0.000510297393798828
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0011792816162109374
# Varianza de la derivada: 0.00036371955871582033
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0008456710815429687
# Varianza de la derivada: 0.0005468402862548828
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.00107120361328125
# Varianza de la derivada: 0.0005340862274169922
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.001005096435546875
# Varianza de la derivada: 0.000358014965057373
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.001207343673706055
# Varianza de la derivada: 0.00039393796920776376
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.000995330810546875
# Varianza de la derivada: 0.0005565905570983887
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0011218303680419922
# Varianza de la derivada: 0.0004858566284179687
#
# =====================================================
# Pendiente para valor esperado: 0.02473655184150506.
# R^2 para valor esperado: 0.2444683156742787.
#
# =====================================================
# Pendiente para derivada: -0.00932872068349715.
# R^2 para derivada: 0.01890177057239028.
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.0009628185272216797
# Varianza de la derivada: 0.0006192222595214844
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.0010150360107421875
# Varianza de la derivada: 0.0005446635246276856
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0011394695281982422
# Varianza de la derivada: 0.0005007052421569825
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0010280670166015627
# Varianza de la derivada: 0.00045483350753784164
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.0010220932006835938
# Varianza de la derivada: 0.00046600065231323234
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.001014335250854492
# Varianza de la derivada: 0.0006508540153503418
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0010755599975585937
# Varianza de la derivada: 0.00035572967529296873
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0008568614959716797
# Varianza de la derivada: 0.0004959193229675292
#
# =====================================================
# Calculando varianzas con 10 qubits.
#
# Varianza del valor esperado: 0.0008598979949951173
# Varianza de la derivada: 0.0004913574218750001
#
# =====================================================
# Pendiente para valor esperado: -0.01815505960528071.
# R^2 para valor esperado: 0.27586729437557.
#
# =====================================================
# Pendiente para derivada: -0.02552956262743328.
# R^2 para derivada: 0.15478105180588328.

# %% [markdown]
# ### We try using less layers

# %%
from qiskit.providers.fake_provider import FakeMontreal

fake_backend = FakeMontreal()

data_noise = []

def low_layers_ansatz_fun(n_qubits):

    return anz.build_deep_ansatz(n_qubits, 2)

for noise_scale in np.linspace(0, 0.05, 6):
    data_noise.append(cf.noisy_variance_vs_nQubits(low_layers_ansatz_fun, fake_backend, noise_scale, 2, 9, observable, 0, 100, print_info=True, plot_info=True, do_regress=False))
# Out:
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.2377681774139404
# Varianza de la derivada: 0.05098344802856445
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.1336441207885742
# Varianza de la derivada: 0.014598421478271483
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.11084170341491699
# Varianza de la derivada: 0.012206211090087888
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.07026865997314453
# Varianza de la derivada: 0.0036156345367431646
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.09708328247070312
# Varianza de la derivada: 0.002015210723876953
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.06288458976745605
# Varianza de la derivada: 0.0005785922050476074
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.040409397506713865
# Varianza de la derivada: 0.000672456645965576
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.043016471862792977
# Varianza de la derivada: 0.0005648609161376953
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.1221666549682617
# Varianza de la derivada: 0.0642387843132019
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.054878805541992176
# Varianza de la derivada: 0.00871980848312378
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.035658125305175786
# Varianza de la derivada: 0.0015577677726745609
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.03040870056152344
# Varianza de la derivada: 0.000555250072479248
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.034031095504760744
# Varianza de la derivada: 0.0004734024047851563
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.027412011718750007
# Varianza de la derivada: 0.0005590510368347168
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.008891563415527343
# Varianza de la derivada: 0.00036911725997924806
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.008044624328613283
# Varianza de la derivada: 0.000429773235321045
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.09045133361816404
# Varianza de la derivada: 0.061244942092895514
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.03755511627197265
# Varianza de la derivada: 0.003240645980834961
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.026417103195190427
# Varianza de la derivada: 0.0006515651702880858
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.008972251510620118
# Varianza de la derivada: 0.0006867953300476073
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.005632633590698243
# Varianza de la derivada: 0.0004960307121276854
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.006149311447143554
# Varianza de la derivada: 0.0005172061920166016
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0013679790496826172
# Varianza de la derivada: 0.00036566123962402335
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.002395631408691406
# Varianza de la derivada: 0.00042647361755371077
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.08830007133483889
# Varianza de la derivada: 0.03064344558715821
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.007908124923706053
# Varianza de la derivada: 0.0012529826164245606
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0033521331787109377
# Varianza de la derivada: 0.0007803477287292483
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.006525486373901367
# Varianza de la derivada: 0.0005274081230163575
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.0022298141479492185
# Varianza de la derivada: 0.0003757129669189453
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0018736186981201171
# Varianza de la derivada: 0.0004504585266113282
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0012012008666992188
# Varianza de la derivada: 0.00044145164489746094
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0010694164276123046
# Varianza de la derivada: 0.0004707656860351563
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.04482402801513672
# Varianza de la derivada: 0.02450767621994018
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.007262607955932618
# Varianza de la derivada: 0.0017065338134765627
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.003972541427612305
# Varianza de la derivada: 0.00043246030807495115
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0019287151336669925
# Varianza de la derivada: 0.00040518522262573243
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.0023380352020263674
# Varianza de la derivada: 0.00044129905700683597
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0012256359100341798
# Varianza de la derivada: 0.0005115856170654297
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.001124586486816406
# Varianza de la derivada: 0.0003558444023132325
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.001092970275878906
# Varianza de la derivada: 0.0004953685760498047
# =====================================================
# Calculando varianzas con 2 qubits.
#
# Varianza del valor esperado: 0.03443731842041015
# Varianza de la derivada: 0.005306219482421874
#
# =====================================================
# Calculando varianzas con 3 qubits.
#
# Varianza del valor esperado: 0.00423453483581543
# Varianza de la derivada: 0.0008470378875732421
#
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.001493986511230469
# Varianza de la derivada: 0.0005214637756347656
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.0021793651580810543
# Varianza de la derivada: 0.0004936862945556641
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.001497306442260742
# Varianza de la derivada: 0.00044226799011230463
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0009874919891357421
# Varianza de la derivada: 0.0005943270683288574
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0009856964111328126
# Varianza de la derivada: 0.0003785728454589844
#
# =====================================================
# Calculando varianzas con 9 qubits.
#
# Varianza del valor esperado: 0.0012067733764648439
# Varianza de la derivada: 0.0005664562225341796

# %% [markdown]
# Plot noise and not noise

# %%
import matplotlib.pyplot as plt
plt.plot(data_noise[0]["n_qubits"], data_noise[0]["var_value"], marker="o", color = "black", label="Libre de ruido")
plt.plot(data_noise[0]["n_qubits"], data_noise[3]["var_value"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ qubits", size=16)
plt.ylabel(r"Var($\langle O\rangle$)", size=16)
plt.title("NIBP para valor esperado", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.show()

plt.plot(data_noise[0]["n_qubits"], data_noise[0]["var_deriv"], marker="o", color = "Black", label="Libre de ruido")
plt.plot(data_noise[0]["n_qubits"], data_noise[3]["var_deriv"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ qubits", size=16)
plt.ylabel(r"Var($\partial_0\langle O\rangle$)", size=16)
plt.title(r"NIBP para derivada respecto $\theta_0$ del valor esperado", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.legend(fontsize="15")
plt.show()

# %% [markdown]
# ## Concentración de varianzas con profundidad del circuito

# %%
data_layers_deep = []
data_layers_deep.append(cf.variance_vs_layers(anz.build_deep_ansatz, 2, 11, 4, observable, 0, 100, True, True, True))


data_layers_Nlocal = []
data_layers_Nlocal.append(cf.variance_vs_layers(anz.build_Nlocal_ansatz, 2, 11, 4, observable, 0, 100, True, True, True))

data_layers_twoLocal = []
data_layers_twoLocal.append(cf.variance_vs_layers(anz.build_twoLocal_ansatz, 2, 11, 4, observable, 0, 100, True, True, True))
# Out:
# =====================================================
# Calculando varianzas con nº capas: 2.
#
# Varianza del valor esperado: 0.0923054692018301
# Varianza de la derivada: 0.00486882444608468
#
# =====================================================
# Calculando varianzas con nº capas: 3.
#
# Varianza del valor esperado: 0.09785213313627056
# Varianza de la derivada: 0.010941159441557435
#
# =====================================================
# Calculando varianzas con nº capas: 4.
#
# Varianza del valor esperado: 0.08321404523689767
# Varianza de la derivada: 0.010356686102713236
#
# =====================================================
# Calculando varianzas con nº capas: 5.
#
# Varianza del valor esperado: 0.08468603567199336
# Varianza de la derivada: 0.014118910140464944
#
# =====================================================
# Calculando varianzas con nº capas: 6.
#
# Varianza del valor esperado: 0.04620512524735605
# Varianza de la derivada: 0.03625413871959258
#
# =====================================================
# Calculando varianzas con nº capas: 7.
#
# Varianza del valor esperado: 0.05936747961376642
# Varianza de la derivada: 0.02428248607969989
#
# =====================================================
# Calculando varianzas con nº capas: 8.
#
# Varianza del valor esperado: 0.05585710517060577
# Varianza de la derivada: 0.015320952506332704
#
# =====================================================
# Calculando varianzas con nº capas: 9.
#
# Varianza del valor esperado: 0.05415502764609207
# Varianza de la derivada: 0.014937533427497953
#
# =====================================================
# Calculando varianzas con nº capas: 10.
#
# Varianza del valor esperado: 0.06256812450181803
# Varianza de la derivada: 0.03228078441039502
#
# =====================================================
# Pendiente para valor esperado: -0.07471087893095413.
# R^2 para valor esperado: 0.5778586915902212.
#
# =====================================================
# Pendiente para derivada: 0.16376554551797323.
# R^2 para derivada: 0.5196244371331356.
# =====================================================
# Calculando varianzas con nº capas: 2.
#
# Varianza del valor esperado: 0.1176816996008744
# Varianza de la derivada: 0.02022068095287244
#
# =====================================================
# Calculando varianzas con nº capas: 3.
#
# Varianza del valor esperado: 0.07770755478884284
# Varianza de la derivada: 0.023609871903143537
#
# =====================================================
# Calculando varianzas con nº capas: 4.
#
# Varianza del valor esperado: 0.07389050376896415
# Varianza de la derivada: 0.021870399003771017
#
# =====================================================
# Calculando varianzas con nº capas: 5.
#
# Varianza del valor esperado: 0.056692218535217664
# Varianza de la derivada: 0.027453722891200943
#
# =====================================================
# Calculando varianzas con nº capas: 6.
#
# Varianza del valor esperado: 0.06447661397432579
# Varianza de la derivada: 0.030487971559583892
#
# =====================================================
# Calculando varianzas con nº capas: 7.
#
# Varianza del valor esperado: 0.07264641984702389
# Varianza de la derivada: 0.030090991281756838
#
# =====================================================
# Calculando varianzas con nº capas: 8.
#
# Varianza del valor esperado: 0.06417756575808435
# Varianza de la derivada: 0.030574903484101114
#
# =====================================================
# Calculando varianzas con nº capas: 9.
#
# Varianza del valor esperado: 0.06136114115528247
# Varianza de la derivada: 0.02328423440185185
#
# =====================================================
# Calculando varianzas con nº capas: 10.
#
# Varianza del valor esperado: 0.062083724154034854
# Varianza de la derivada: 0.027714313242995954
#
# =====================================================
# Pendiente para valor esperado: -0.055006998031801785.
# R^2 para valor esperado: 0.48435852620033654.
#
# =====================================================
# Pendiente para derivada: 0.033018701797236476.
# R^2 para derivada: 0.33654140125782855.
# =====================================================
# Calculando varianzas con nº capas: 2.
#
# Varianza del valor esperado: 0.2549867395597279
# Varianza de la derivada: 0.00876530459659255
#
# =====================================================
# Calculando varianzas con nº capas: 3.
#
# Varianza del valor esperado: 0.22814767183013224
# Varianza de la derivada: 0.01994311674867029
#
# =====================================================
# Calculando varianzas con nº capas: 4.
#
# Varianza del valor esperado: 0.22049113400634904
# Varianza de la derivada: 0.025621187547237252
#
# =====================================================
# Calculando varianzas con nº capas: 5.
#
# Varianza del valor esperado: 0.1998915753065242
# Varianza de la derivada: 0.045749674912031614
#
# =====================================================
# Calculando varianzas con nº capas: 6.
#
# Varianza del valor esperado: 0.2199130306993202
# Varianza de la derivada: 0.05632968964778231
#
# =====================================================
# Calculando varianzas con nº capas: 7.
#
# Varianza del valor esperado: 0.21203322103510505
# Varianza de la derivada: 0.0465754309743136
#
# =====================================================
# Calculando varianzas con nº capas: 8.
#
# Varianza del valor esperado: 0.21914661947018454
# Varianza de la derivada: 0.047570224660629525
#
# =====================================================
# Calculando varianzas con nº capas: 9.
#
# Varianza del valor esperado: 0.2174270502231656
# Varianza de la derivada: 0.07800947743488454
#
# =====================================================
# Calculando varianzas con nº capas: 10.
#
# Varianza del valor esperado: 0.19649407320011705
# Varianza de la derivada: 0.056225078975757396
#
# =====================================================
# Pendiente para valor esperado: -0.01899952201654572.
# R^2 para valor esperado: 0.4714280411303079.
#
# =====================================================
# Pendiente para derivada: 0.21302580977189103.
# R^2 para derivada: 0.7443699079755857.

# %%
from qiskit.providers.fake_provider import FakeMontreal

fake_backend = FakeMontreal()

noise_scale = 0.02

data_noise_layers_deep = []
data_noise_layers_deep.append(cf.noisy_variance_vs_layers(anz.build_deep_ansatz, fake_backend, noise_scale, 2, 10, 4, observable, 0, 100, True, True, True))


data_noise_layers_Nlocal = []
data_noise_layers_Nlocal.append(cf.noisy_variance_vs_layers(anz.build_Nlocal_ansatz, fake_backend, noise_scale, 2, 10, 4, observable, 0, 100, True, True, True))


data_noise_layers_twoLocal = []
data_noise_layers_twoLocal.append(cf.noisy_variance_vs_layers(anz.build_twoLocal_ansatz, fake_backend, noise_scale, 2, 10, 4, observable, 0, 100, True, True, True))
# Out:
# =====================================================
# Calculando varianzas con nº capas: 2.
#
# Varianza del valor esperado: 0.02671655998229981
# Varianza de la derivada: 0.0006029514312744142
#
# =====================================================
# Calculando varianzas con nº capas: 3.
#
# Varianza del valor esperado: 0.004098008728027344
# Varianza de la derivada: 0.0006611384391784668
#
# =====================================================
# Calculando varianzas con nº capas: 4.
#
# Varianza del valor esperado: 0.0021121658325195312
# Varianza de la derivada: 0.0006122947692871095
#
# =====================================================
# Calculando varianzas con nº capas: 5.
#
# Varianza del valor esperado: 0.0016725811004638675
# Varianza de la derivada: 0.0005951395988464355
#
# =====================================================
# Calculando varianzas con nº capas: 6.
#
# Varianza del valor esperado: 0.0010582256317138673
# Varianza de la derivada: 0.00040900144577026357
#
# =====================================================
# Calculando varianzas con nº capas: 7.
#
# Varianza del valor esperado: 0.0012275527954101562
# Varianza de la derivada: 0.0005042361259460449
#
# =====================================================
# Calculando varianzas con nº capas: 8.
#
# Varianza del valor esperado: 0.0008695220947265625
# Varianza de la derivada: 0.0003953170776367187
#
# =====================================================
# Calculando varianzas con nº capas: 9.
#
# Varianza del valor esperado: 0.0010418224334716797
# Varianza de la derivada: 0.00047217903137207034
#
# =====================================================
# Calculando varianzas con nº capas: 10.
#
# Varianza del valor esperado: 0.0009962810516357422
# Varianza de la derivada: 0.0005141230583190918
#
# =====================================================
# Pendiente para valor esperado: -0.32248371896757905.
# R^2 para valor esperado: 0.6557576776525011.
#
# =====================================================
# Pendiente para derivada: -0.04480189562218704.
# R^2 para derivada: 0.45013880879770135.
# =====================================================
# Calculando varianzas con nº capas: 2.
#
# Varianza del valor esperado: 0.027038856124877927
# Varianza de la derivada: 0.0031948856353759764
#
# =====================================================
# Calculando varianzas con nº capas: 3.
#
# Varianza del valor esperado: 0.011399772262573245
# Varianza de la derivada: 0.003521718597412109
#
# =====================================================
# Calculando varianzas con nº capas: 4.
#
# Varianza del valor esperado: 0.004755039596557617
# Varianza de la derivada: 0.001481077098846436
#
# =====================================================
# Calculando varianzas con nº capas: 5.
#
# Varianza del valor esperado: 0.0022625926971435546
# Varianza de la derivada: 0.0009825228691101072
#
# =====================================================
# Calculando varianzas con nº capas: 6.
#
# Varianza del valor esperado: 0.0016378921508789059
# Varianza de la derivada: 0.0007463732719421386
#
# =====================================================
# Calculando varianzas con nº capas: 7.
#
# Varianza del valor esperado: 0.0010454448699951174
# Varianza de la derivada: 0.0005261279106140136
#
# =====================================================
# Calculando varianzas con nº capas: 8.
#
# Varianza del valor esperado: 0.0010139907836914062
# Varianza de la derivada: 0.000525341033935547
#
# =====================================================
# Calculando varianzas con nº capas: 9.
#
# Varianza del valor esperado: 0.0011704116821289062
# Varianza de la derivada: 0.0007280360221862793
#
# =====================================================
# Calculando varianzas con nº capas: 10.
#
# Varianza del valor esperado: 0.001050315475463867
# Varianza de la derivada: 0.00043782987594604485
#
# =====================================================
# Pendiente para valor esperado: -0.39473570422873927.
# R^2 para valor esperado: 0.8176888298857714.
#
# =====================================================
# Pendiente para derivada: -0.25627499818888805.
# R^2 para derivada: 0.8238112452908036.
# =====================================================
# Calculando varianzas con nº capas: 2.
#
# Varianza del valor esperado: 0.1056056121826172
# Varianza de la derivada: 0.0060137866973876955
#
# =====================================================
# Calculando varianzas con nº capas: 3.
#
# Varianza del valor esperado: 0.06719040641784668
# Varianza de la derivada: 0.004980949783325195
#
# =====================================================
# Calculando varianzas con nº capas: 4.
#
# Varianza del valor esperado: 0.037757651901245116
# Varianza de la derivada: 0.006065630340576171
#
# =====================================================
# Calculando varianzas con nº capas: 5.
#
# Varianza del valor esperado: 0.03524966850280762
# Varianza de la derivada: 0.0037694911003112795
#
# =====================================================
# Calculando varianzas con nº capas: 6.
#
# Varianza del valor esperado: 0.017707582092285158
# Varianza de la derivada: 0.005094339275360107
#
# =====================================================
# Calculando varianzas con nº capas: 7.
#
# Varianza del valor esperado: 0.011271133422851562
# Varianza de la derivada: 0.002928139114379883
#
# =====================================================
# Calculando varianzas con nº capas: 8.
#
# Varianza del valor esperado: 0.013439594650268553
# Varianza de la derivada: 0.003362739086151123
#
# =====================================================
# Calculando varianzas con nº capas: 9.
#
# Varianza del valor esperado: 0.007054978942871094
# Varianza de la derivada: 0.002363221740722656
#
# =====================================================
# Calculando varianzas con nº capas: 10.
#
# Varianza del valor esperado: 0.005345497131347655
# Varianza de la derivada: 0.002070974254608154
#
# =====================================================
# Pendiente para valor esperado: -0.3650232613992214.
# R^2 para valor esperado: 0.9693199217637603.
#
# =====================================================
# Pendiente para derivada: -0.1322210713924443.
# R^2 para derivada: 0.8288726688510011.

# %%
plt.plot(data_layers_deep[0]["layers"], data_layers_deep[0]["var_value"], marker="o", color = "black", label="Libre de ruido")
plt.plot(data_noise_layers_deep[0]["layers"], data_noise_layers_deep[0]["var_value"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ capas", size=16)
plt.ylabel(r"Var($\langle O\rangle$)", size=16)
plt.title("Deep Ansatz, valor esperado", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.show()

plt.plot(data_layers_deep[0]["layers"], data_layers_deep[0]["var_deriv"], marker="o", color = "Black", label="Libre de ruido")
plt.plot(data_noise_layers_deep[0]["layers"], data_noise_layers_deep[0]["var_deriv"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ capas", size=16)
plt.ylabel(r"Var($\partial_0\langle O\rangle$)", size=16)
plt.title("Deep Ansatz, derivada", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.legend(fontsize="15")
plt.show()

# %%
plt.plot(data_layers_Nlocal[0]["layers"], data_layers_Nlocal[0]["var_value"], marker="o", color = "black", label="Libre de ruido")
plt.plot(data_noise_layers_Nlocal[0]["layers"], data_noise_layers_Nlocal[0]["var_value"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ capas", size=16)
plt.ylabel(r"Var($\langle O\rangle$)", size=16)
plt.title("N-local, valor esperado", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.show()

plt.plot(data_layers_Nlocal[0]["layers"], data_layers_Nlocal[0]["var_deriv"], marker="o", color = "Black", label="Libre de ruido")
plt.plot(data_noise_layers_Nlocal[0]["layers"], data_noise_layers_Nlocal[0]["var_deriv"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ capas", size=16)
plt.ylabel(r"Var($\partial_0\langle O\rangle$)", size=16)
plt.title("N-local, derivada", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.legend(fontsize="15")
plt.show()

# %%
plt.plot(data_layers_twoLocal[0]["layers"], data_layers_twoLocal[0]["var_value"], marker="o", color = "black", label="Libre de ruido")
plt.plot(data_noise_layers_twoLocal[0]["layers"], data_noise_layers_twoLocal[0]["var_value"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ capas", size=16)
plt.ylabel(r"Var($\langle O\rangle$)", size=16)
plt.title("2-local, valor esperado", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.show()

plt.plot(data_layers_twoLocal[0]["layers"], data_layers_twoLocal[0]["var_deriv"], marker="o", color = "Black", label="Libre de ruido")
plt.plot(data_noise_layers_twoLocal[0]["layers"], data_noise_layers_twoLocal[0]["var_deriv"], marker="o", color = "red", label=r"Ruido del backend Montreal $\times$ 0.02")

plt.xlabel(r"$N$ capas", size=16)
plt.ylabel(r"Var($\partial_0\langle O\rangle$)", size=16)
plt.title("2-local, derivada", size=16)
plt.xticks(fontsize="15")
plt.yticks(fontsize="15")

plt.yscale("log")
plt.legend(fontsize="15")
plt.show()

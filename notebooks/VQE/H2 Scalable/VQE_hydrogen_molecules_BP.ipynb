# %%
# Para cargar lo necesario
import pickle

import sys
import os

# Agrega el path al directorio raíz del proyecto
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "../../")))

# Ahora puedes importar
import customFunctions as cf

#from qiskit.circuit.library import TwoLocal
#from qiskit.circuit import QuantumCircuit

# %%
from qiskit.circuit.library import TwoLocal
from qiskit.circuit import QuantumCircuit

def crear_ansatz_nlocal(num_qubits: int, reps: int = 1) -> tuple[QuantumCircuit, int]:
    """
    Crea un ansatz N-local (TwoLocal) con un número dado de qubits y repeticiones.
    Devuelve el circuito y el número de parámetros libres.

    Args:
        num_qubits (int): Número de qubits del circuito.
        reps (int): Número de repeticiones (capas) del ansatz.

    Returns:
        tuple: (QuantumCircuit, número de parámetros del circuito)
    """
    ansatz = TwoLocal(num_qubits,
                      rotation_blocks='ry',
                      entanglement_blocks='cz',
                      entanglement='linear',
                      reps=reps,
                      insert_barriers=True)
    
    return ansatz, ansatz.num_parameters

# %%
# 0.719

with open("hamiltonian0.719.pkl", "rb") as f:
    hamiltonian = pickle.load(f)

print(hamiltonian)
# Out:
# SparsePauliOp(['IIII', 'IIIZ', 'IIZI', 'IIZZ', 'IZII', 'IZIZ', 'ZIII', 'ZIIZ', 'YYYY', 'XXYY', 'YYXX', 'XXXX', 'IZZI', 'ZIZI', 'ZZII'],
#               coeffs=[-0.80499838+0.j,  0.17472226+0.j, -0.23347838+0.j,  0.12184887+0.j,
#   0.17472226+0.j,  0.16970294+0.j, -0.23347838+0.j,  0.16685625+0.j,
#   0.04500738+0.j,  0.04500738+0.j,  0.04500738+0.j,  0.04500738+0.j,
#   0.16685625+0.j,  0.17539742+0.j,  0.12184887+0.j])

# %%
data = []

for j in range(8):
    data.append(cf.variance_vs_nQubits(crear_ansatz_nlocal, 4, 8, hamiltonian, j, 100, True, True))
# Out:
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.08446990724904982
# Varianza de la derivada: 0.029488903466892674
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.07100806105545338
# Varianza de la derivada: 0.0037989841895034403
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.09353513928401051
# Varianza de la derivada: 1.3604668015829355e-32
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.09244164633714175
# Varianza de la derivada: 1.3045787220092483e-32
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.07316411901287
# Varianza de la derivada: 1.4191388128912343e-32
#
# =====================================================
# None
# Pendiente para valor esperado: -0.0023596252216347316.
# $R^2$ para valor esperado: -0.02900631154930236.
#
# =====================================================
# None
# Pendiente para derivada: -20.746168427480583.
# $R^2$ para valor esperado: -0.8699849719348067.
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.08464665010369134
# Varianza de la derivada: 0.03399025924043409
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.07804510600085697
# Varianza de la derivada: 0.025669724665503782
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.06610722085046447
# Varianza de la derivada: 0.005071282797231113
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.08123225908776988
# Varianza de la derivada: 1.2115081574467352e-32
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.05876682053522415
# Varianza de la derivada: 1.4037024843869702e-32
#
# =====================================================
# None
# Pendiente para valor esperado: -0.06897907244777608.
# $R^2$ para valor esperado: -0.7089666765992315.
#
# =====================================================
# None
# Pendiente para derivada: -20.975227059118563.
# $R^2$ para valor esperado: -0.8734821759018084.
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0922282164228919
# Varianza de la derivada: 0.03632223192078376
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.08691804430815832
# Varianza de la derivada: 0.036538044676768286
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.06386582932327821
# Varianza de la derivada: 0.028327881798644695
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0779300572367537
# Varianza de la derivada: 0.0028235269644552607
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.08637050665492914
# Varianza de la derivada: 1.0296382594558735e-32
#
# =====================================================
# None
# Pendiente para valor esperado: -0.02403936515607712.
# $R^2$ para valor esperado: -0.26245360712721394.
#
# =====================================================
# None
# Pendiente para derivada: -14.323674756575125.
# $R^2$ para valor esperado: -0.7267723823473594.
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.0755647093656821
# Varianza de la derivada: 0.03968189261642187
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.09006326496452656
# Varianza de la derivada: 0.03483630441314974
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.07138020360192493
# Varianza de la derivada: 0.02815532663379935
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.07876970888561007
# Varianza de la derivada: 0.025481569379450054
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.08005636430238715
# Varianza de la derivada: 0.007149340930014371
#
# =====================================================
# None
# Pendiente para valor esperado: -0.0018500702459878671.
# $R^2$ para valor esperado: -0.03399179433515898.
#
# =====================================================
# None
# Pendiente para derivada: -0.3740454258706957.
# $R^2$ para valor esperado: -0.8615990948705311.
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.09118731134209662
# Varianza de la derivada: 0.02599342337411656
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.06685296704589913
# Varianza de la derivada: 0.037342494385367374
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.06819843251904315
# Varianza de la derivada: 0.032721502387620116
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.06992352797384019
# Varianza de la derivada: 0.03211776497728134
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.07174801092598658
# Varianza de la derivada: 0.02623773428107739
#
# =====================================================
# None
# Pendiente para valor esperado: -0.043460474965115826.
# $R^2$ para valor esperado: -0.5432587341129519.
#
# =====================================================
# None
# Pendiente para derivada: -0.013201252375802986.
# $R^2$ para valor esperado: -0.1342017030272424.
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.09098974059216733
# Varianza de la derivada: 0.02706770290217301
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.05946989874828922
# Varianza de la derivada: 4.9892370767317983e-33
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.07406328082230189
# Varianza de la derivada: 0.033879026534230826
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.07924185599587219
# Varianza de la derivada: 0.03420944185583806
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.07107728720622347
# Varianza de la derivada: 0.03124215107859878
#
# =====================================================
# None
# Pendiente para valor esperado: -0.020692348156617826.
# $R^2$ para valor esperado: -0.21036892674009028.
#
# =====================================================
# None
# Pendiente para derivada: 7.128962533944463.
# $R^2$ para valor esperado: 0.3553989112673057.
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.06965024148869128
# Varianza de la derivada: 0.02459479320494192
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.06356661406233148
# Varianza de la derivada: 0.01583388484295203
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.09183281155101655
# Varianza de la derivada: 7.540709067056009e-33
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.06216425508045328
# Varianza de la derivada: 0.0318445714368446
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.0869946436753338
# Varianza de la derivada: 0.03113120091243843
#
# =====================================================
# None
# Pendiente para valor esperado: 0.042241252582968826.
# $R^2$ para valor esperado: 0.37060400839050334.
#
# =====================================================
# None
# Pendiente para derivada: 0.11700662696849023.
# $R^2$ para valor esperado: 0.005886518772676689.
# =====================================================
# Calculando varianzas con 4 qubits.
#
# Varianza del valor esperado: 0.07016897680475447
# Varianza de la derivada: 0.03746527634144924
#
# =====================================================
# Calculando varianzas con 5 qubits.
#
# Varianza del valor esperado: 0.07502892842969232
# Varianza de la derivada: 0.0227325458389767
#
# =====================================================
# Calculando varianzas con 6 qubits.
#
# Varianza del valor esperado: 0.07509482764929688
# Varianza de la derivada: 5.207156049939215e-33
#
# =====================================================
# Calculando varianzas con 7 qubits.
#
# Varianza del valor esperado: 0.0831528384266618
# Varianza de la derivada: 5.983864337211142e-33
#
# =====================================================
# Calculando varianzas con 8 qubits.
#
# Varianza del valor esperado: 0.09316202960554076
# Varianza de la derivada: 0.0347264201708071
#
# =====================================================
# None
# Pendiente para valor esperado: 0.0669674476745764.
# $R^2$ para valor esperado: 0.9557813417597563.
#
# =====================================================
# None
# Pendiente para derivada: -7.0564111364048046.
# $R^2$ para valor esperado: -0.28775201511898424.

# %%
cf.VQE_minimization_BP(crear_ansatz_nlocal, 4, 10, hamiltonian, "all")
# Out:
# =====================================================
# Preparando ejecución para 4 qubits.
# Se usarán 8 parámetros
# Fin ejecución con 4 qubits. Mínimo encontrado: -1.8537095141830282
# =====================================================
#
# =====================================================
# Preparando ejecución para 5 qubits.
# Se usarán 10 parámetros
# Fin ejecución con 5 qubits. Mínimo encontrado: -1.8537093650502294
# =====================================================
#
# =====================================================
# Preparando ejecución para 6 qubits.
# Se usarán 12 parámetros
# Fin ejecución con 6 qubits. Mínimo encontrado: -1.8537095132081627
# =====================================================
#
# =====================================================
# Preparando ejecución para 7 qubits.
# Se usarán 14 parámetros
# Fin ejecución con 7 qubits. Mínimo encontrado: -1.8537095151099539
# =====================================================
#
# =====================================================
# Preparando ejecución para 8 qubits.
# Se usarán 16 parámetros
# Fin ejecución con 8 qubits. Mínimo encontrado: -1.8537095145729625
# =====================================================
#
# =====================================================
# Preparando ejecución para 9 qubits.
# Se usarán 18 parámetros
# Fin ejecución con 9 qubits. Mínimo encontrado: -1.8537095078225652
# =====================================================
#
# =====================================================
# Preparando ejecución para 10 qubits.
# Se usarán 20 parámetros
# Fin ejecución con 10 qubits. Mínimo encontrado: -1.8537095147720937
# =====================================================
